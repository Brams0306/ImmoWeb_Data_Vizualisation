# %%
import pandas as pd
import seaborn as sns
import numpy as np
from statistics import median
import matplotlib.pyplot as plt

# %%
def transform_locality_to_provinces(postal_code : str) -> str:
    temp = int(postal_code)
    if temp >= 1000 and temp <= 1299:
        return "Bruxelles"
    elif temp >= 1300 and temp <= 1499:
        return "Brabant wallon"
    elif (temp >= 1500 and temp <= 1999) or (temp >= 3000 and temp <= 3499):
        return "Brabant flamand"
    elif temp >= 2000 and temp <= 2999:
        return "Anvers"
    elif temp >= 3500 and temp <= 3999:
        return "Limbourg"
    elif temp >= 4000 and temp <= 4999:
        return "Liege"
    elif temp >= 5000 and temp <= 5680:
        return "Namur"
    elif (temp >= 6000 and temp <= 6599) or (temp >= 7000 and temp <= 7999):
        return "Hainaut"
    elif temp >= 6600 and temp <= 6999:
        return "Luxembourg"
    elif temp >= 8000 and temp <= 8999:
        return "Flandre occidentale"
    elif temp >= 9000 and temp <= 9999:
        return "Flandre orientale"
    else:
        return "Error"

# %%
data_immo = pd.read_csv('data_a.csv')

# %%
data_immo
# Out:
#        Unnamed: 0 To rent To sell     Price  Number of rooms  Living Area  \
# 0         1610665    True   False     485.0              1.0         40.0
# 1         2718948    True   False     790.0              2.0        140.0
# 2         3229637    True   False     900.0              3.0        103.0
# 3         3860205    True   False     520.0              2.0         50.0
# 4         4141598    True   False     760.0              1.0         55.0
# ...           ...     ...     ...       ...              ...          ...
# 78187    10316113   False    True  349000.0              4.0          NaN
# 78188    10316130    True   False     590.0              1.0          NaN
# 78189    10316135    True   False     595.0              1.0          NaN
# 78190    10316134    True   False    1150.0              3.0        800.0
# 78191    10316136    True   False    1590.0              3.0        100.0
#
#       Fully equipped kitchen Furnished  Open fire  Terrace  \
# 0                       True     False      False    False
# 1                       True     False      False    False
# 2                        NaN     False      False    False
# 3                       True     False      False    False
# 4                       True       NaN      False     True
# ...                      ...       ...        ...      ...
# 78187                    NaN       NaN      False    False
# 78188                   True       NaN      False    False
# 78189                    NaN       NaN      False    False
# 78190                   True     False      False     True
# 78191                   True     False      False     True
#
#        Area of the terrace  Garden  Area of the garden  Surface of the land  \
# 0                      0.0   False                 0.0                  NaN
# 1                      0.0   False                 0.0                  NaN
# 2                      0.0    True               330.0                400.0
# 3                      0.0   False                 0.0                  NaN
# 4                     30.0    True             10000.0                  NaN
# ...                    ...     ...                 ...                  ...
# 78187                  0.0    True                 1.0                  NaN
# 78188                  0.0   False                 0.0                  NaN
# 78189                  0.0   False                 0.0                  NaN
# 78190                  1.0    True                 1.0                  NaN
# 78191                 28.0   False                 0.0                  NaN
#
#        Surface area of the plot of land  Number of facades  Swimming pool  \
# 0                                   NaN                2.0          False
# 1                                   NaN                2.0          False
# 2                                 400.0                3.0          False
# 3                                   NaN                2.0          False
# 4                                   NaN                2.0          False
# ...                                 ...                ...            ...
# 78187                               NaN                NaN          False
# 78188                               NaN                1.0          False
# 78189                               NaN                NaN          False
# 78190                               NaN                4.0          False
# 78191                               NaN                2.0          False
#
#        State of the building  zipcode         type
# 0          \nExcellentétat\n     4020       Studio
# 1                    \nBon\n     3200  Appartement
# 2                    \nBon\n     7020       Maison
# 3                    \nBon\n     6900  Appartement
# 4                        NaN     1470  Appartement
# ...                      ...      ...          ...
# 78187      \nExcellentétat\n     3550  Appartement
# 78188      \nExcellentétat\n     4000  Appartement
# 78189                    NaN     9000  Appartement
# 78190  \nFraîchementrénové\n     4052     Bungalow
# 78191      \nExcellentétat\n     1030       Duplex
#
# [78192 rows x 20 columns]

# %%
data_immo['zipcode'] = data_immo['zipcode'].map(transform_locality_to_provinces)

# %%
data_immo
# Out:
#        Unnamed: 0 To rent To sell     Price  Number of rooms  Living Area  \
# 0         1610665    True   False     485.0              1.0         40.0
# 1         2718948    True   False     790.0              2.0        140.0
# 2         3229637    True   False     900.0              3.0        103.0
# 3         3860205    True   False     520.0              2.0         50.0
# 4         4141598    True   False     760.0              1.0         55.0
# ...           ...     ...     ...       ...              ...          ...
# 78187    10316113   False    True  349000.0              4.0          NaN
# 78188    10316130    True   False     590.0              1.0          NaN
# 78189    10316135    True   False     595.0              1.0          NaN
# 78190    10316134    True   False    1150.0              3.0        800.0
# 78191    10316136    True   False    1590.0              3.0        100.0
#
#       Fully equipped kitchen Furnished  Open fire  Terrace  \
# 0                       True     False      False    False
# 1                       True     False      False    False
# 2                        NaN     False      False    False
# 3                       True     False      False    False
# 4                       True       NaN      False     True
# ...                      ...       ...        ...      ...
# 78187                    NaN       NaN      False    False
# 78188                   True       NaN      False    False
# 78189                    NaN       NaN      False    False
# 78190                   True     False      False     True
# 78191                   True     False      False     True
#
#        Area of the terrace  Garden  Area of the garden  Surface of the land  \
# 0                      0.0   False                 0.0                  NaN
# 1                      0.0   False                 0.0                  NaN
# 2                      0.0    True               330.0                400.0
# 3                      0.0   False                 0.0                  NaN
# 4                     30.0    True             10000.0                  NaN
# ...                    ...     ...                 ...                  ...
# 78187                  0.0    True                 1.0                  NaN
# 78188                  0.0   False                 0.0                  NaN
# 78189                  0.0   False                 0.0                  NaN
# 78190                  1.0    True                 1.0                  NaN
# 78191                 28.0   False                 0.0                  NaN
#
#        Surface area of the plot of land  Number of facades  Swimming pool  \
# 0                                   NaN                2.0          False
# 1                                   NaN                2.0          False
# 2                                 400.0                3.0          False
# 3                                   NaN                2.0          False
# 4                                   NaN                2.0          False
# ...                                 ...                ...            ...
# 78187                               NaN                NaN          False
# 78188                               NaN                1.0          False
# 78189                               NaN                NaN          False
# 78190                               NaN                4.0          False
# 78191                               NaN                2.0          False
#
#        State of the building            zipcode         type
# 0          \nExcellentétat\n              Liege       Studio
# 1                    \nBon\n    Brabant flamand  Appartement
# 2                    \nBon\n            Hainaut       Maison
# 3                    \nBon\n         Luxembourg  Appartement
# 4                        NaN     Brabant wallon  Appartement
# ...                      ...                ...          ...
# 78187      \nExcellentétat\n           Limbourg  Appartement
# 78188      \nExcellentétat\n              Liege  Appartement
# 78189                    NaN  Flandre orientale  Appartement
# 78190  \nFraîchementrénové\n              Liege     Bungalow
# 78191      \nExcellentétat\n          Bruxelles       Duplex
#
# [78192 rows x 20 columns]

# %%
data1 = data_immo.drop(columns=['Unnamed: 0', 'Number of facades', 'Open fire','Surface area of the plot of land','Area of the garden','Area of the terrace','Furnished','Fully equipped kitchen','To rent'])
data1
# Out:
#       To sell     Price  Number of rooms  Living Area  Terrace  Garden  \
# 0       False     485.0              1.0         40.0    False   False
# 1       False     790.0              2.0        140.0    False   False
# 2       False     900.0              3.0        103.0    False    True
# 3       False     520.0              2.0         50.0    False   False
# 4       False     760.0              1.0         55.0     True    True
# ...       ...       ...              ...          ...      ...     ...
# 78187    True  349000.0              4.0          NaN    False    True
# 78188   False     590.0              1.0          NaN    False   False
# 78189   False     595.0              1.0          NaN    False   False
# 78190   False    1150.0              3.0        800.0     True    True
# 78191   False    1590.0              3.0        100.0     True   False
#
#        Surface of the land  Swimming pool  State of the building  \
# 0                      NaN          False      \nExcellentétat\n
# 1                      NaN          False                \nBon\n
# 2                    400.0          False                \nBon\n
# 3                      NaN          False                \nBon\n
# 4                      NaN          False                    NaN
# ...                    ...            ...                    ...
# 78187                  NaN          False      \nExcellentétat\n
# 78188                  NaN          False      \nExcellentétat\n
# 78189                  NaN          False                    NaN
# 78190                  NaN          False  \nFraîchementrénové\n
# 78191                  NaN          False      \nExcellentétat\n
#
#                  zipcode         type
# 0                  Liege       Studio
# 1        Brabant flamand  Appartement
# 2                Hainaut       Maison
# 3             Luxembourg  Appartement
# 4         Brabant wallon  Appartement
# ...                  ...          ...
# 78187           Limbourg  Appartement
# 78188              Liege  Appartement
# 78189  Flandre orientale  Appartement
# 78190              Liege     Bungalow
# 78191          Bruxelles       Duplex
#
# [78192 rows x 11 columns]

# %%
data1 = data1.replace({"Excellent" : 1,"Good": 2,"\nExcellentétat\n" : 1,"\nBon\n" : 2,"\nFraîchementrénové\n" : 3, "\nÀrafraîchir\n" :4, "\nÀrénover\n" : 5,"\nÀrestaurer\n" : 6 })
data1
# Out:
#       To sell     Price  Number of rooms  Living Area  Terrace  Garden  \
# 0       False     485.0              1.0         40.0    False   False
# 1       False     790.0              2.0        140.0    False   False
# 2       False     900.0              3.0        103.0    False    True
# 3       False     520.0              2.0         50.0    False   False
# 4       False     760.0              1.0         55.0     True    True
# ...       ...       ...              ...          ...      ...     ...
# 78187    True  349000.0              4.0          NaN    False    True
# 78188   False     590.0              1.0          NaN    False   False
# 78189   False     595.0              1.0          NaN    False   False
# 78190   False    1150.0              3.0        800.0     True    True
# 78191   False    1590.0              3.0        100.0     True   False
#
#        Surface of the land  Swimming pool  State of the building  \
# 0                      NaN          False                    1.0
# 1                      NaN          False                    2.0
# 2                    400.0          False                    2.0
# 3                      NaN          False                    2.0
# 4                      NaN          False                    NaN
# ...                    ...            ...                    ...
# 78187                  NaN          False                    1.0
# 78188                  NaN          False                    1.0
# 78189                  NaN          False                    NaN
# 78190                  NaN          False                    3.0
# 78191                  NaN          False                    1.0
#
#                  zipcode         type
# 0                  Liege       Studio
# 1        Brabant flamand  Appartement
# 2                Hainaut       Maison
# 3             Luxembourg  Appartement
# 4         Brabant wallon  Appartement
# ...                  ...          ...
# 78187           Limbourg  Appartement
# 78188              Liege  Appartement
# 78189  Flandre orientale  Appartement
# 78190              Liege     Bungalow
# 78191          Bruxelles       Duplex
#
# [78192 rows x 11 columns]

# %%
data1 = data1.astype({'To sell' : bool})
data1
# Out:
#        To sell     Price  Number of rooms  Living Area  Terrace  Garden  \
# 0        False     485.0              1.0         40.0    False   False
# 1        False     790.0              2.0        140.0    False   False
# 2        False     900.0              3.0        103.0    False    True
# 3        False     520.0              2.0         50.0    False   False
# 4        False     760.0              1.0         55.0     True    True
# ...        ...       ...              ...          ...      ...     ...
# 78187     True  349000.0              4.0          NaN    False    True
# 78188    False     590.0              1.0          NaN    False   False
# 78189    False     595.0              1.0          NaN    False   False
# 78190    False    1150.0              3.0        800.0     True    True
# 78191    False    1590.0              3.0        100.0     True   False
#
#        Surface of the land  Swimming pool  State of the building  \
# 0                      NaN          False                    1.0
# 1                      NaN          False                    2.0
# 2                    400.0          False                    2.0
# 3                      NaN          False                    2.0
# 4                      NaN          False                    NaN
# ...                    ...            ...                    ...
# 78187                  NaN          False                    1.0
# 78188                  NaN          False                    1.0
# 78189                  NaN          False                    NaN
# 78190                  NaN          False                    3.0
# 78191                  NaN          False                    1.0
#
#                  zipcode         type
# 0                  Liege       Studio
# 1        Brabant flamand  Appartement
# 2                Hainaut       Maison
# 3             Luxembourg  Appartement
# 4         Brabant wallon  Appartement
# ...                  ...          ...
# 78187           Limbourg  Appartement
# 78188              Liege  Appartement
# 78189  Flandre orientale  Appartement
# 78190              Liege     Bungalow
# 78191          Bruxelles       Duplex
#
# [78192 rows x 11 columns]

# %%
col_float = data1.select_dtypes(float).columns.to_list()

# %%
n2 = int(np.ceil(len(col_float)/2))

plt.figure(figsize=(15, 5*n2))



for i in np.arange(len(col_float)):
    col = col_float[i]
    

    
    plt.subplot(n2 ,2, i+1)
    sns.kdeplot(data=data1, x=col, fill=True)

plt.show()

data1[col_float].describe()
# Out:
#                Price  Number of rooms   Living Area  Surface of the land  \
# count   74200.000000     73277.000000  62305.000000         3.434300e+04
# mean   250608.766604         2.865265    164.025921         1.552214e+03
# std    213654.482931         7.666023    244.303414         1.588625e+04
# min        25.000000         1.000000      1.000000         1.000000e+00
# 25%      2500.000000         2.000000     90.000000         2.140000e+02
# 50%    245000.000000         3.000000    128.000000         4.500000e+02
# 75%    365504.250000         3.000000    188.000000         9.600000e+02
# max    999999.000000      2020.000000  25325.000000         2.400000e+06
#
#        State of the building
# count           53060.000000
# mean                2.222522
# std                 1.303981
# min                 1.000000
# 25%                 1.000000
# 50%                 2.000000
# 75%                 3.000000
# max                 6.000000

# %%
data2 = data1[data1['To sell']==True]
data2
# Out:
#        To sell     Price  Number of rooms  Living Area  Terrace  Garden  \
# 152       True       NaN              NaN          NaN    False   False
# 278       True       NaN              NaN          NaN    False   False
# 360       True       NaN              2.0        117.0     True   False
# 667       True       NaN              NaN          NaN    False   False
# 1498      True       NaN              1.0         65.0     True   False
# ...        ...       ...              ...          ...      ...     ...
# 78173     True  249000.0              2.0          NaN     True   False
# 78174     True  529000.0              2.0        134.0    False   False
# 78184     True  649000.0              4.0        206.0     True    True
# 78186     True  325000.0              2.0         91.0    False   False
# 78187     True  349000.0              4.0          NaN    False    True
#
#        Surface of the land  Swimming pool  State of the building  \
# 152                    NaN          False                    NaN
# 278                    NaN          False                    NaN
# 360                    NaN          False                    3.0
# 667                    NaN          False                    NaN
# 1498                   NaN          False                    3.0
# ...                    ...            ...                    ...
# 78173                  NaN          False                    NaN
# 78174                  NaN          False                    2.0
# 78184                520.0          False                    1.0
# 78186                  NaN          False                    NaN
# 78187                  NaN          False                    1.0
#
#                zipcode                     type
# 152    Brabant flamand  AssistentiewoningenKast
# 278    Brabant flamand  Projetneuf-Appartements
# 360              Namur              Appartement
# 667              Liege                SUITESLIF
# 1498             Namur                   Duplex
# ...                ...                      ...
# 78173           Anvers              Appartement
# 78174           Anvers              Appartement
# 78184  Brabant flamand                   Maison
# 78186           Anvers              Appartement
# 78187         Limbourg              Appartement
#
# [60997 rows x 11 columns]

# %%
n2 = int(np.ceil(len(col_float)/2))

plt.figure(figsize=(15, 5*n2))



for i in np.arange(len(col_float)):
    col = col_float[i]
    

    
    plt.subplot(n2 ,2, i+1)
    sns.kdeplot(data=data2, x=col, fill=True)

plt.show()

data2[col_float].describe()
# Out:
#                Price  Number of rooms   Living Area  Surface of the land  \
# count   57005.000000     56714.000000  48893.000000         3.250500e+04
# mean   325856.801035         3.078023    177.214080         1.600566e+03
# std    186989.910410         8.685288    237.748411         1.632528e+04
# min      1000.000000         1.000000      1.000000         1.000000e+00
# 25%    203500.000000         2.000000     98.000000         2.170000e+02
# 50%    295000.000000         3.000000    140.000000         4.540000e+02
# 75%    400000.000000         4.000000    200.000000         9.750000e+02
# max    999999.000000      2020.000000  22617.000000         2.400000e+06
#
#        State of the building
# count           40593.000000
# mean                2.402434
# std                 1.387961
# min                 1.000000
# 25%                 1.000000
# 50%                 2.000000
# 75%                 3.000000
# max                 6.000000

# %%
data2 = data2.drop(columns=['Surface of the land','Number of rooms'])

# %%
plt.figure(figsize=(10, 5))

plt.title('Missing Values\n')

sns.heatmap(data2.isnull(), cbar=False)
plt.show()

# %%
data2[['Price']].describe().T
# Out:
#          count           mean           std     min       25%       50%  \
# Price  57005.0  325856.801035  186989.91041  1000.0  203500.0  295000.0
#
#             75%       max
# Price  400000.0  999999.0

# %%
plt.figure(figsize=(30, 10))
sns.countplot(data=data2, x='Price')
plt.xticks(rotation=45, ha="right") 
plt.show()

# %%
data3 = data3.rename(columns={'zipcode': 'Province'})

# %%
plt.figure(figsize=(20, 8))
sns.countplot(data=data3, x='Province')
plt.xticks(rotation=45, ha="right") 
plt.show()

data3['Province'].value_counts()
# Out:
# Anvers                 10548
# Flandre occidentale    10147
# Flandre orientale       8800
# Hainaut                 7798
# Liege                   5710
# Brabant flamand         5623
# Limbourg                3283
# Brabant wallon          2581
# Namur                   2501
# Bruxelles               2269
# Luxembourg              1736
# Error                      1
# Name: Province, dtype: int64

# %%
    sns.catplot(data= data3, kind="bar", x="State of the building", y="Price")
    plt.title("Price comparaison of status of properties")
    plt.xlabel("States of the building")
    plt.xticks(rotation=45)
    plt.ylabel("Price")
    plt.show()

# %%
plt.figure(figsize=(18,10))
plt.title('Correlation Variable\n')
sns.heatmap(data3.corr(),
            vmin=-1,
            vmax=1,
            cmap='coolwarm',
            cbar=False,
            annot=True)
plt.show()

# %%
data3
# Out:
#        To sell     Price  Living Area  Terrace  Garden  Swimming pool  \
# 152       True       NaN          NaN    False   False          False
# 278       True       NaN          NaN    False   False          False
# 360       True       NaN        117.0     True   False          False
# 667       True       NaN          NaN    False   False          False
# 1498      True       NaN         65.0     True   False          False
# ...        ...       ...          ...      ...     ...            ...
# 78173     True  249000.0          NaN     True   False          False
# 78174     True  529000.0        134.0    False   False          False
# 78184     True  649000.0        206.0     True    True          False
# 78186     True  325000.0         91.0    False   False          False
# 78187     True  349000.0          NaN    False    True          False
#
#        State of the building         Province                     type
# 152                      NaN  Brabant flamand  AssistentiewoningenKast
# 278                      NaN  Brabant flamand  Projetneuf-Appartements
# 360                      3.0            Namur              Appartement
# 667                      NaN            Liege                SUITESLIF
# 1498                     3.0            Namur                   Duplex
# ...                      ...              ...                      ...
# 78173                    NaN           Anvers              Appartement
# 78174                    2.0           Anvers              Appartement
# 78184                    1.0  Brabant flamand                   Maison
# 78186                    NaN           Anvers              Appartement
# 78187                    1.0         Limbourg              Appartement
#
# [60997 rows x 9 columns]
